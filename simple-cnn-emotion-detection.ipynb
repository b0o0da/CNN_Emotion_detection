# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import models, layers, optimizers, callbacks, preprocessing, applications
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from warnings import filterwarnings
filterwarnings("ignore")
import random as rand
seed = 42
import random as rand
# Out:
# 2025-07-31 17:02:15.863678: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753981336.237970      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753981336.345733      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train = r"/kaggle/input/balanced-fer-dataset-7575-grayscale/train"
test = r"/kaggle/input/balanced-fer-dataset-7575-grayscale/test"
val = r"/kaggle/input/balanced-fer-dataset-7575-grayscale/val"

# %%
import os
import csv
path_train = train
path_test = test
path_val = val


csv_file_train = "train.csv"
csv_file_test = "test.csv"
csv_file_val = "val.csv"

def make_csv_file(csv_file , main_folder):
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['path', 'label'])


        for label in os.listdir(main_folder):
            folder_path = os.path.join(main_folder, label)
            if os.path.isdir(folder_path):
                for image_name in os.listdir(folder_path):
                    image_path = os.path.join(folder_path, image_name)
                    if image_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                        writer.writerow([image_path, label])



make_csv_file(csv_file_train , path_train)
make_csv_file(csv_file_test , path_test)
make_csv_file(csv_file_val , path_val)

# %%
train = pd.read_csv(r"/kaggle/working/train.csv")
test = pd.read_csv(r"/kaggle/working/test.csv")
val = pd.read_csv(r"/kaggle/working/val.csv")

# %%
train
# Out:
#                                                     path     label
# 0      /kaggle/input/balanced-fer-dataset-7575-graysc...  surprise
# 1      /kaggle/input/balanced-fer-dataset-7575-graysc...  surprise
# 2      /kaggle/input/balanced-fer-dataset-7575-graysc...  surprise
# 3      /kaggle/input/balanced-fer-dataset-7575-graysc...  surprise
# 4      /kaggle/input/balanced-fer-dataset-7575-graysc...  surprise
# ...                                                  ...       ...
# 45299  /kaggle/input/balanced-fer-dataset-7575-graysc...     happy
# 45300  /kaggle/input/balanced-fer-dataset-7575-graysc...     happy
# 45301  /kaggle/input/balanced-fer-dataset-7575-graysc...     happy
# 45302  /kaggle/input/balanced-fer-dataset-7575-graysc...     happy
# 45303  /kaggle/input/balanced-fer-dataset-7575-graysc...     happy
#
# [45304 rows x 2 columns]

# %%
print(train.shape)
print(test.shape)
print(val.shape)
# Out:
# (45304, 2)
# (6286, 2)
# (11326, 2)

# %%
Total_Images = train.shape[0]
print(f"Total Train images :{Total_Images}\n")

num_classes = train['label'].nunique()
print(f"Unique Classes: {num_classes}\n")

classes = train['label'].unique()
print("Classes:", classes)
# Out:
# Total Train images :45304
#
# Unique Classes: 7
#
# Classes: ['surprise' 'fear' 'angry' 'neutral' 'sad' 'disgust' 'happy']

# %%
train["label"].value_counts()
# Out:
# label
# surprise    6472
# fear        6472
# angry       6472
# neutral     6472
# sad         6472
# disgust     6472
# happy       6472
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=train, x='label', order=train['label'].value_counts().index)
plt.title("Number of Images per Class")
plt.xticks(rotation=45)
plt.show()

# %%
# -- show sample of data --

plt.figure(figsize=(13 , 8))

for i in range(0 , 16):
    num = rand.randint(0, len(train["path"]) - 1)
    image_path = train.iloc[num]["path"]
    image = cv2.imread(image_path)

    if image is not None:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # -- convert image to BGR to RGB --
        h, w = image.shape[:2]
        plt.subplot(4, 4, i+1)
        plt.imshow(image)
        plt.title(f"{train.iloc[num]['label']} {w}x{h}", fontsize=8)  # -- image label and dimention --
        plt.axis("off")
    else:
        print(f"Image at {image_path} not found!")

plt.tight_layout()
plt.show()

# %%
# -- Reading data -- 

IMG_SIZE = (75, 75)
BATCH_SIZE = 32


train_ds = preprocessing.image_dataset_from_directory(
    f'{train}',
    shuffle=True,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    seed=33,
    label_mode='categorical',
    color_mode='grayscale'
)

val_ds = preprocessing.image_dataset_from_directory(
    f'{val}',
    shuffle=False,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    color_mode='grayscale'
)

test_ds = preprocessing.image_dataset_from_directory(
    f'{test}',
    shuffle=False,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    color_mode='grayscale'
)
# Out:
# Found 45304 files belonging to 7 classes.
# I0000 00:00:1753981374.630960      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1753981374.631716      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 11326 files belonging to 7 classes.
# Found 6286 files belonging to 7 classes.

# %%
# from tensorflow.keras import layers

# data_augmentation = tf.keras.Sequential([
#     tf.keras.layers.RandomFlip("horizontal"),
#     tf.keras.layers.RandomRotation(0.1),
#     tf.keras.layers.RandomZoom(0.1),
#     tf.keras.layers.RandomContrast(0.2),
#     tf.keras.layers.RandomBrightness(factor=0.1),
# ])

# %%
# -- Model Architecture 


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, Input

model = Sequential([
    Input(shape=(75, 75, 1)),

    Conv2D(32, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(32, (3, 3), padding='same', activation='relu'),  
    MaxPooling2D((2, 2)),
    Dropout(0.25),  

    Conv2D(64, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    Conv2D(256, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(256, (3, 3), padding='same', activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

# %%
# -- Summarize model --

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 75, 75, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 75, 75, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 37, 37, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 37, 37, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 18, 18, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 18, 18, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 18, 18, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 18, 18, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 18, 18, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 9, 9, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 9, 9, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 9, 9, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,207,399 (4.61 MB)
#  Trainable params: 1,206,439 (4.60 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# -- Model compiling --
from tensorflow.keras.optimizers import Adam

model.compile(optimizer="Adam",
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# -- call backs (EarlyStopping , ModelCheckpoint , ReduceLROnPlateau)

my_callbacks  = [
    
    EarlyStopping(patience=8, restore_best_weights=True, verbose=1),
    ModelCheckpoint('best_model.keras', save_best_only=True, verbose=1),
    ReduceLROnPlateau(factor=0.5, patience=3, verbose=1)
]

# %%
# -- model Fit --

history = model.fit(
    train_ds,
    epochs=60,
    validation_data=val_ds,
    callbacks=[my_callbacks ]
)
# Out:
# Epoch 1/60
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753981391.980744     103 service.cc:148] XLA service 0x7830d8012780 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753981391.982015     103 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1753981391.982034     103 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1753981392.761443     103 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    5/1416 ━━━━━━━━━━━━━━━━━━━━ 46s 33ms/step - accuracy: 0.1495 - loss: 2.4203
# I0000 00:00:1753981401.569870     103 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1657 - loss: 1.9800
# Epoch 1: val_loss improved from inf to 1.84442, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 88s 51ms/step - accuracy: 0.1657 - loss: 1.9800 - val_accuracy: 0.2428 - val_loss: 1.8444 - learning_rate: 0.0010
# Epoch 2/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2221 - loss: 1.8405
# Epoch 2: val_loss improved from 1.84442 to 1.73192, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.2222 - loss: 1.8404 - val_accuracy: 0.2939 - val_loss: 1.7319 - learning_rate: 0.0010
# Epoch 3/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3110 - loss: 1.7023
# Epoch 3: val_loss improved from 1.73192 to 1.46554, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.3110 - loss: 1.7022 - val_accuracy: 0.4287 - val_loss: 1.4655 - learning_rate: 0.0010
# Epoch 4/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4185 - loss: 1.4942
# Epoch 4: val_loss improved from 1.46554 to 1.37558, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.4185 - loss: 1.4941 - val_accuracy: 0.4695 - val_loss: 1.3756 - learning_rate: 0.0010
# Epoch 5/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4795 - loss: 1.3630
# Epoch 5: val_loss improved from 1.37558 to 1.29844, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.4795 - loss: 1.3629 - val_accuracy: 0.4997 - val_loss: 1.2984 - learning_rate: 0.0010
# Epoch 6/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5210 - loss: 1.2574
# Epoch 6: val_loss improved from 1.29844 to 1.27598, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.5210 - loss: 1.2573 - val_accuracy: 0.5156 - val_loss: 1.2760 - learning_rate: 0.0010
# Epoch 7/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5556 - loss: 1.1734
# Epoch 7: val_loss improved from 1.27598 to 1.04203, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.5556 - loss: 1.1734 - val_accuracy: 0.5960 - val_loss: 1.0420 - learning_rate: 0.0010
# Epoch 8/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5782 - loss: 1.1124
# Epoch 8: val_loss improved from 1.04203 to 1.03620, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.5782 - loss: 1.1124 - val_accuracy: 0.6127 - val_loss: 1.0362 - learning_rate: 0.0010
# Epoch 9/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6020 - loss: 1.0613
# Epoch 9: val_loss improved from 1.03620 to 0.99357, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6020 - loss: 1.0613 - val_accuracy: 0.6248 - val_loss: 0.9936 - learning_rate: 0.0010
# Epoch 10/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6164 - loss: 1.0174
# Epoch 10: val_loss improved from 0.99357 to 0.96633, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6164 - loss: 1.0173 - val_accuracy: 0.6361 - val_loss: 0.9663 - learning_rate: 0.0010
# Epoch 11/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6277 - loss: 0.9808
# Epoch 11: val_loss did not improve from 0.96633
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6277 - loss: 0.9808 - val_accuracy: 0.6310 - val_loss: 0.9711 - learning_rate: 0.0010
# Epoch 12/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6472 - loss: 0.9385
# Epoch 12: val_loss improved from 0.96633 to 0.90533, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6472 - loss: 0.9385 - val_accuracy: 0.6611 - val_loss: 0.9053 - learning_rate: 0.0010
# Epoch 13/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6569 - loss: 0.9153
# Epoch 13: val_loss improved from 0.90533 to 0.88144, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6569 - loss: 0.9152 - val_accuracy: 0.6680 - val_loss: 0.8814 - learning_rate: 0.0010
# Epoch 14/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6687 - loss: 0.8864
# Epoch 14: val_loss did not improve from 0.88144
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6687 - loss: 0.8864 - val_accuracy: 0.6715 - val_loss: 0.8947 - learning_rate: 0.0010
# Epoch 15/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6803 - loss: 0.8574
# Epoch 15: val_loss improved from 0.88144 to 0.82381, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6803 - loss: 0.8574 - val_accuracy: 0.6954 - val_loss: 0.8238 - learning_rate: 0.0010
# Epoch 16/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6866 - loss: 0.8382
# Epoch 16: val_loss did not improve from 0.82381
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6866 - loss: 0.8382 - val_accuracy: 0.6955 - val_loss: 0.8304 - learning_rate: 0.0010
# Epoch 17/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6947 - loss: 0.8112
# Epoch 17: val_loss improved from 0.82381 to 0.81299, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.6947 - loss: 0.8112 - val_accuracy: 0.7002 - val_loss: 0.8130 - learning_rate: 0.0010
# Epoch 18/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7006 - loss: 0.8016
# Epoch 18: val_loss did not improve from 0.81299
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.7006 - loss: 0.8016 - val_accuracy: 0.6822 - val_loss: 0.8767 - learning_rate: 0.0010
# Epoch 19/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7159 - loss: 0.7733
# Epoch 19: val_loss did not improve from 0.81299
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.7159 - loss: 0.7733 - val_accuracy: 0.6956 - val_loss: 0.8422 - learning_rate: 0.0010
# Epoch 20/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7180 - loss: 0.7612
# Epoch 20: val_loss did not improve from 0.81299
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.7181 - loss: 0.7612 - val_accuracy: 0.7010 - val_loss: 0.8501 - learning_rate: 0.0010
# Epoch 21/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7405 - loss: 0.7034
# Epoch 21: val_loss improved from 0.81299 to 0.75513, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.7406 - loss: 0.7034 - val_accuracy: 0.7334 - val_loss: 0.7551 - learning_rate: 5.0000e-04
# Epoch 22/60
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7528 - loss: 0.6645
# Epoch 22: val_loss improved from 0.75513 to 0.75471, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.7528 - loss: 0.6645 - val_accuracy: 0.7394 - val_loss: 0.7547 - learning_rate: 5.0000e-04
# Epoch 23/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7629 - loss: 0.6449
# Epoch 23: val_loss did not improve from 0.75471
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.7629 - loss: 0.6449 - val_accuracy: 0.7402 - val_loss: 0.7568 - learning_rate: 5.0000e-04
# Epoch 24/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7735 - loss: 0.6249
# Epoch 24: val_loss improved from 0.75471 to 0.74860, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.7735 - loss: 0.6249 - val_accuracy: 0.7432 - val_loss: 0.7486 - learning_rate: 5.0000e-04
# Epoch 25/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7704 - loss: 0.6170
# Epoch 25: val_loss improved from 0.74860 to 0.71963, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.7704 - loss: 0.6169 - val_accuracy: 0.7519 - val_loss: 0.7196 - learning_rate: 5.0000e-04
# Epoch 26/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7784 - loss: 0.5937
# Epoch 26: val_loss did not improve from 0.71963
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.7784 - loss: 0.5936 - val_accuracy: 0.7582 - val_loss: 0.7216 - learning_rate: 5.0000e-04
# Epoch 27/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7835 - loss: 0.5828
# Epoch 27: val_loss did not improve from 0.71963
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.7835 - loss: 0.5828 - val_accuracy: 0.7568 - val_loss: 0.7229 - learning_rate: 5.0000e-04
# Epoch 28/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7911 - loss: 0.5724
# Epoch 28: val_loss improved from 0.71963 to 0.71489, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.7911 - loss: 0.5724 - val_accuracy: 0.7621 - val_loss: 0.7149 - learning_rate: 5.0000e-04
# Epoch 29/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7975 - loss: 0.5572
# Epoch 29: val_loss improved from 0.71489 to 0.71345, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.7975 - loss: 0.5572 - val_accuracy: 0.7657 - val_loss: 0.7135 - learning_rate: 5.0000e-04
# Epoch 30/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8022 - loss: 0.5462
# Epoch 30: val_loss did not improve from 0.71345
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8022 - loss: 0.5461 - val_accuracy: 0.7582 - val_loss: 0.7289 - learning_rate: 5.0000e-04
# Epoch 31/60
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8058 - loss: 0.5395
# Epoch 31: val_loss improved from 0.71345 to 0.70882, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8058 - loss: 0.5395 - val_accuracy: 0.7670 - val_loss: 0.7088 - learning_rate: 5.0000e-04
# Epoch 32/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8069 - loss: 0.5283
# Epoch 32: val_loss did not improve from 0.70882
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8069 - loss: 0.5283 - val_accuracy: 0.7636 - val_loss: 0.7355 - learning_rate: 5.0000e-04
# Epoch 33/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8110 - loss: 0.5153
# Epoch 33: val_loss improved from 0.70882 to 0.69979, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8110 - loss: 0.5153 - val_accuracy: 0.7743 - val_loss: 0.6998 - learning_rate: 5.0000e-04
# Epoch 34/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8146 - loss: 0.5048
# Epoch 34: val_loss did not improve from 0.69979
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8146 - loss: 0.5048 - val_accuracy: 0.7666 - val_loss: 0.7232 - learning_rate: 5.0000e-04
# Epoch 35/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8187 - loss: 0.4989
# Epoch 35: val_loss did not improve from 0.69979
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8187 - loss: 0.4988 - val_accuracy: 0.7741 - val_loss: 0.7013 - learning_rate: 5.0000e-04
# Epoch 36/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8233 - loss: 0.4892
# Epoch 36: val_loss did not improve from 0.69979
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8233 - loss: 0.4892 - val_accuracy: 0.7733 - val_loss: 0.7306 - learning_rate: 5.0000e-04
# Epoch 37/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8337 - loss: 0.4648
# Epoch 37: val_loss improved from 0.69979 to 0.68546, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8337 - loss: 0.4647 - val_accuracy: 0.7901 - val_loss: 0.6855 - learning_rate: 2.5000e-04
# Epoch 38/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8389 - loss: 0.4434
# Epoch 38: val_loss improved from 0.68546 to 0.68525, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8389 - loss: 0.4433 - val_accuracy: 0.7885 - val_loss: 0.6852 - learning_rate: 2.5000e-04
# Epoch 39/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8450 - loss: 0.4319
# Epoch 39: val_loss did not improve from 0.68525
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8450 - loss: 0.4318 - val_accuracy: 0.7888 - val_loss: 0.6907 - learning_rate: 2.5000e-04
# Epoch 40/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8469 - loss: 0.4311
# Epoch 40: val_loss did not improve from 0.68525
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8469 - loss: 0.4311 - val_accuracy: 0.7888 - val_loss: 0.6881 - learning_rate: 2.5000e-04
# Epoch 41/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8512 - loss: 0.4149
# Epoch 41: val_loss improved from 0.68525 to 0.68515, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8512 - loss: 0.4149 - val_accuracy: 0.7937 - val_loss: 0.6851 - learning_rate: 2.5000e-04
# Epoch 42/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8541 - loss: 0.4062
# Epoch 42: val_loss did not improve from 0.68515
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8541 - loss: 0.4062 - val_accuracy: 0.7946 - val_loss: 0.6856 - learning_rate: 2.5000e-04
# Epoch 43/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8574 - loss: 0.3991
# Epoch 43: val_loss did not improve from 0.68515
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8574 - loss: 0.3991 - val_accuracy: 0.7960 - val_loss: 0.7031 - learning_rate: 2.5000e-04
# Epoch 44/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8597 - loss: 0.3930
# Epoch 44: val_loss did not improve from 0.68515
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8597 - loss: 0.3930 - val_accuracy: 0.7975 - val_loss: 0.6920 - learning_rate: 2.5000e-04
# Epoch 45/60
# 1415/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8628 - loss: 0.3825
# Epoch 45: val_loss improved from 0.68515 to 0.67702, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8628 - loss: 0.3824 - val_accuracy: 0.8015 - val_loss: 0.6770 - learning_rate: 1.2500e-04
# Epoch 46/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8654 - loss: 0.3738
# Epoch 46: val_loss did not improve from 0.67702
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8654 - loss: 0.3738 - val_accuracy: 0.8008 - val_loss: 0.6828 - learning_rate: 1.2500e-04
# Epoch 47/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8675 - loss: 0.3784
# Epoch 47: val_loss did not improve from 0.67702
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8675 - loss: 0.3784 - val_accuracy: 0.8040 - val_loss: 0.6773 - learning_rate: 1.2500e-04
# Epoch 48/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8691 - loss: 0.3652
# Epoch 48: val_loss did not improve from 0.67702
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8691 - loss: 0.3651 - val_accuracy: 0.8041 - val_loss: 0.6800 - learning_rate: 1.2500e-04
# Epoch 49/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8716 - loss: 0.3593
# Epoch 49: val_loss did not improve from 0.67702
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8716 - loss: 0.3593 - val_accuracy: 0.8075 - val_loss: 0.6770 - learning_rate: 6.2500e-05
# Epoch 50/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8760 - loss: 0.3553
# Epoch 50: val_loss improved from 0.67702 to 0.67588, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8760 - loss: 0.3553 - val_accuracy: 0.8063 - val_loss: 0.6759 - learning_rate: 6.2500e-05
# Epoch 51/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8763 - loss: 0.3480
# Epoch 51: val_loss did not improve from 0.67588
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8763 - loss: 0.3480 - val_accuracy: 0.8077 - val_loss: 0.6811 - learning_rate: 6.2500e-05
# Epoch 52/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8776 - loss: 0.3532
# Epoch 52: val_loss did not improve from 0.67588
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8776 - loss: 0.3532 - val_accuracy: 0.8062 - val_loss: 0.6781 - learning_rate: 6.2500e-05
# Epoch 53/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8782 - loss: 0.3379
# Epoch 53: val_loss did not improve from 0.67588
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8782 - loss: 0.3379 - val_accuracy: 0.8101 - val_loss: 0.6814 - learning_rate: 6.2500e-05
# Epoch 54/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8810 - loss: 0.3382
# Epoch 54: val_loss did not improve from 0.67588
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8810 - loss: 0.3382 - val_accuracy: 0.8096 - val_loss: 0.6786 - learning_rate: 3.1250e-05
# Epoch 55/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8792 - loss: 0.3397
# Epoch 55: val_loss improved from 0.67588 to 0.67339, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8792 - loss: 0.3397 - val_accuracy: 0.8080 - val_loss: 0.6734 - learning_rate: 3.1250e-05
# Epoch 56/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8787 - loss: 0.3429
# Epoch 56: val_loss did not improve from 0.67339
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8787 - loss: 0.3428 - val_accuracy: 0.8079 - val_loss: 0.6755 - learning_rate: 3.1250e-05
# Epoch 57/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8786 - loss: 0.3378
# Epoch 57: val_loss improved from 0.67339 to 0.67202, saving model to best_model.keras
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8786 - loss: 0.3378 - val_accuracy: 0.8103 - val_loss: 0.6720 - learning_rate: 3.1250e-05
# Epoch 58/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8841 - loss: 0.3317
# Epoch 58: val_loss did not improve from 0.67202
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.8841 - loss: 0.3317 - val_accuracy: 0.8088 - val_loss: 0.6751 - learning_rate: 3.1250e-05
# Epoch 59/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8840 - loss: 0.3309
# Epoch 59: val_loss did not improve from 0.67202
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8840 - loss: 0.3309 - val_accuracy: 0.8094 - val_loss: 0.6761 - learning_rate: 3.1250e-05
# Epoch 60/60
# 1414/1416 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8850 - loss: 0.3276
# Epoch 60: val_loss did not improve from 0.67202
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1416/1416 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.8850 - loss: 0.3276 - val_accuracy: 0.8111 - val_loss: 0.6758 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 57.

# %%
# -- Plot training vs validation accuracy --
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title('Accuracy over epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# -- Plot training vs validation loss --
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss over epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(test_ds)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.8146 - loss: 0.6702
# Loss: 0.6704524755477905
# Accuracy: 0.8141902685165405

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

X_test = []
y_test = []

for images, labels in test_ds:
    X_test.append(images.numpy())
    y_test.append(labels.numpy())

X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)

# -- predict test data -- 
y_pred = model.predict(X_test)


y_true_labels = np.argmax(y_test, axis=1)
y_pred_labels = np.argmax(y_pred, axis=1)

# -- Confusion Matrix --
cm = confusion_matrix(y_true_labels, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_ds.class_names)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step

# %%
from sklearn.metrics import classification_report

X_test = []
y_true = []

for images, labels in test_ds:
    X_test.append(images.numpy())
    y_true.append(labels.numpy())

X_test = np.concatenate(X_test, axis=0)
y_true = np.argmax(np.concatenate(y_true, axis=0), axis=1)


y_pred_probs = model.predict(X_test, batch_size=64, verbose=0)
y_pred = np.argmax(y_pred_probs, axis=1)


class_names = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.80      0.76      0.78       898
#      disgust       0.96      1.00      0.98       898
#         fear       0.75      0.69      0.72       898
#        happy       0.87      0.87      0.87       898
#          sad       0.72      0.80      0.76       898
#     surprise       0.69      0.68      0.68       898
#      neutral       0.90      0.91      0.90       898
#
#     accuracy                           0.81      6286
#    macro avg       0.81      0.81      0.81      6286
# weighted avg       0.81      0.81      0.81      6286
